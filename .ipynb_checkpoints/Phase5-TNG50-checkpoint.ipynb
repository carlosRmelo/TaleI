# %%
from dynesty import NestedSampler
import numpy as np
import pickle

# %%
path = "8/model1/Lens/"

with open(path+f'phase5/sampler_phase5.pickle','rb') as f:
    sampler = pickle.load(f)
    f.close()

with open(path+f'phase5/phase5.pickle','rb') as f:
    ph5 = pickle.load(f)
    f.close()

with open(path+f'phase5/log_likelihood_phase5.pickle','rb') as f:
    log_like = pickle.load(f)
    f.close()
with open(path+f'phase5/prior_transform_phase5.pickle','rb') as f:
    prior_transform = pickle.load(f)
    f.close()

with open(path+f'phase5/CombinedModel_phase5.pickle','rb') as f:
    CM = pickle.load(f)
    f.close()
    
with open(path+f'phase5/priors_phase5.pickle','rb') as f:
    priors = pickle.load(f)
    f.close()
    

def resume_dlogz(sampler):
        results = sampler.results
        logz_remain = np.max(sampler.live_logl) + results.logvol[-1]
        delta_logz = np.logaddexp(results.logz[-1], logz_remain) - results.logz[-1]
        
        return delta_logz

# %%
sampler = sampler["sampler"]
sampler.results.summary()
# Out:
# Summary
# =======
# nlive: 500
# niter: 573405
# ncall: 575754
# eff(%): 99.506
# logz: -999988005000208448540744114696803970619277013240645147164608221892754011610258651901792270854127616.000 +/- 1413498743080214348871342226614217404735750668288.000

# %%
# Generate a new set of results with statistical+sampling uncertainties.
from dynesty import plotting as dyplot
from dynesty import utils as dyfunc


labels = list(priors.keys())

parsRes = priors.copy()

results_sim = dyfunc.jitter_run(dyfunc.resample_run(sampler.results))


samples_sim = results_sim.samples
weights = np.exp(results_sim.logwt - results_sim.logz[-1])  # normalized weights
mean, cov = dyfunc.mean_and_cov(samples_sim, weights)

new_samples = dyfunc.resample_equal(samples_sim, weights)
for i, key in enumerate(parsRes.keys()):
    parsRes[key] = mean[i]
    print(key, parsRes[key])
# Out:
# /home/carlosmelo/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/dynesty/utils.py:1029: UserWarning: Weights do not sum to 1 and have been renormalized.
#   warnings.warn("Weights do not sum to 1 and have been renormalized.")
# inc 77.3546746479651
# beta -0.15973937371848912
# ml 2.517151733104844
# log_rho_s -3.6698011354173024
# rs 15.68065701042424
# slope 1.53936221917112

# %%
from IPython.display import display, Math

for i in range(sampler.npdim):
    mcmc = np.percentile(new_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
# Out:
# $\displaystyle \mathrm{inc} = 77.332_{-8.166}^{6.840}$
# $\displaystyle \mathrm{beta} = -0.146_{-0.060}^{0.019}$
# $\displaystyle \mathrm{ml} = 2.528_{-0.192}^{0.239}$
# $\displaystyle \mathrm{log_rho_s} = -3.696_{-0.402}^{0.239}$
# $\displaystyle \mathrm{rs} = 15.749_{-3.400}^{2.847}$
# $\displaystyle \mathrm{slope} = 1.544_{-0.114}^{0.106}$

# %%
fig, axes = dyplot.traceplot(results=results_sim, smooth=0.08,
                             show_titles=True,
                             labels=labels,
                             )
fig.tight_layout()

# %%
# Plot the 2-D marginalized posteriors.
cfig, caxes = dyplot.cornerplot(results_sim, smooth=0.08,
                                show_titles=True,labels=labels,
                                
                               )

# %%
a = dyplot.cornerbound(sampler.results, it=sampler.it, labels=labels,
                       prior_transform=prior_transform,
                       show_live=True, live_color="red",)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 a = dyplot.cornerbound(sampler.results, it=sampler.it, labels=labels,
#       2                        prior_transform=prior_transform,
#       3                        show_live=True, live_color="red",)
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/dynesty/plotting.py:1940, in cornerbound(results, it, idx, dims, prior_transform, periodic, reflective, ndraws, color, plot_kwargs, labels, label_kwargs, max_n_ticks, use_math_text, show_live, live_color, live_kwargs, span, fig)
#    1938 if it is not None:
#    1939     if it >= nsamps:
# -> 1940         raise ValueError("The iteration requested goes beyond the "
#    1941                          "number of iterations in the run.")
#    1942     # Extract bound iterations.
#    1943     try:
#
# ValueError: The iteration requested goes beyond the number of iterations in the run.

# %%
import autolens as al

# %%
ph5.parsSource
# Out:
# {'pixels': 92.25332037857352,
#  'weight_floor': 0.0017292367084775437,
#  'weight_power': 11.821390724294464,
#  'inner_coefficient': 0.0004919049142117463,
#  'outer_coefficient': 16.11857672822734,
#  'signal_scale': 0.05735327526112483}

# %%
adp_pix = ph5.source_pix(pixels=int(ph5.parsSource["pixels"]),
                            weight_floor=ph5.parsSource["weight_floor"],
                            weight_power=ph5.parsSource["weight_power"]
                            )

adp_reg = ph5.source_reg(inner_coefficient=ph5.parsSource["inner_coefficient"],
                            outer_coefficient=ph5.parsSource["outer_coefficient"],
                            signal_scale=ph5.parsSource["signal_scale"]
                            )

source_model = al.Galaxy(redshift=CM.Lens_model.z_s,
                            pixelization=adp_pix, regularization=adp_reg,
                            hyper_model_image=ph5.hyper_image_2d,
                            hyper_galaxy_image=ph5.hyper_image_2d,
                            )

CM.source_galaxy(source_model=source_model)  #Setting the source galaxy model

# %%
CM.quiet = False
CM.Updt_Model(parsRes)
# Out:
#  ---------------------------------
#
# ParsDic: {'inc': 77.66430239909488, 'beta': -0.15973693173950926, 'ml': 2.3334661894056485, 'log_rho_s': -3.568201136137065, 'rs': 17.02591143851375, 'qDM': 1.0, 'slope': 1.4997073197447537, 'gamma': 1.0}
#
#  ---------------------------------
#
# Parameters Updated!

# %%
CM.run_current(quiet=False)
# Out:
# jam_axi_rms elapsed time sec: 0.08
# No PSF convolution: sigmapsf == 0;
# inc=77.7 beta_z=-0.16 M/L=1.00 BH=0.00e+00 chi2/DOF=0.505
# Total mass MGE: 3.913e+12
# Including the following Analytical DM profile:
# #------------------------------------#
# EllNFWGeneralized
# centre: (0.0, 0.0)
# elliptical_comps: (0.0, 5.551115123125783e-17)
# kappa_s: 0.003587663715208979
# scale_radius: 17.02591143851375
# inner_slope: 1.4997073197447537
#
#
# An exception ocurres in Pyautolens_figure_of_merit().
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/dyLens/Combined/CombinedModel.py:392, in Model.Pyautolens_figure_of_merit(self)
#     391 fit = al.FitImaging(dataset=self.masked_imaging, tracer=tracer)
# --> 392 print(fit.figure_of_merit)
#     393 self.Fit = fit #Turn fit  accessible to analysis
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/numba_util.py:72, in profile_func.<locals>.wrapper(obj, *args, **kwargs)
#      71 if obj.profiling_dict is None:
# ---> 72     return func(obj, *args, **kwargs)
#      74 repeats = conf.instance["general"]["profiling"]["repeats"]
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/fit/fit_dataset.py:241, in FitDataset.figure_of_merit(self)
#     240     return self.log_likelihood
# --> 241 return self.log_evidence
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/fit/fit_dataset.py:229, in FitDataset.log_evidence(self)
#     227 if self.inversion is not None:
#     228     return fit_util.log_evidence_from(
# --> 229         chi_squared=self.chi_squared,
#     230         regularization_term=self.inversion.regularization_term,
#     231         log_curvature_regularization_term=self.inversion.log_det_curvature_reg_matrix_term,
#     232         log_regularization_term=self.inversion.log_det_regularization_matrix_term,
#     233         noise_normalization=self.noise_normalization,
#     234     )
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/fit/fit_dataset.py:163, in FitDataset.chi_squared(self)
#     160     return fit_util.chi_squared_with_mask_from(
#     161         chi_squared_map=self.chi_squared_map, mask=self.mask
#     162     )
# --> 163 return fit_util.chi_squared_from(chi_squared_map=self.chi_squared_map)
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/fit/fit_dataset.py:151, in FitDataset.chi_squared_map(self)
#     147     return fit_util.chi_squared_map_with_mask_from(
#     148         residual_map=self.residual_map, noise_map=self.noise_map, mask=self.mask
#     149     )
#     150 return fit_util.chi_squared_map_from(
# --> 151     residual_map=self.residual_map, noise_map=self.noise_map
#     152 )
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/fit/fit_dataset.py:122, in FitDataset.residual_map(self)
#     119     return fit_util.residual_map_with_mask_from(
#     120         data=self.data, model_data=self.model_data, mask=self.mask
#     121     )
# --> 122 return fit_util.residual_map_from(data=self.data, model_data=self.model_data)
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autolens/imaging/fit_imaging.py:138, in FitImaging.model_data(self)
#     136 if self.tracer.has_pixelization:
# --> 138     return self.blurred_image + self.inversion.mapped_reconstructed_data
#     140 return self.blurred_image
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoconf/tools/decorators.py:16, in CachedProperty.__get__(self, obj, cls)
#      15     return self
# ---> 16 value = obj.__dict__[self.func.__name__] = self.func(obj)
#      17 return value
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/numba_util.py:72, in profile_func.<locals>.wrapper(obj, *args, **kwargs)
#      71 if obj.profiling_dict is None:
# ---> 72     return func(obj, *args, **kwargs)
#      74 repeats = conf.instance["general"]["profiling"]["repeats"]
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/inversion/inversion/abstract.py:170, in AbstractInversion.mapped_reconstructed_data(self)
#     158 """
#     159 Using the reconstructed source pixel fluxes we map each source pixel flux back to the image plane and
#     160 reconstruct the image data.
#    (...)
#     168     The reconstructed image data which the inversion fits.
#     169 """
# --> 170 return sum(self.mapped_reconstructed_data_dict.values())
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/inversion/inversion/abstract.py:134, in AbstractInversion.mapped_reconstructed_data_dict(self)
#     121 """
#     122 Using the reconstructed source pixel fluxes we map each source pixel flux back to the image plane and
#     123 reconstruct the image data.
#    (...)
#     131     The reconstructed image data which the inversion fits.
#     132 """
#     133 return self.leq.mapped_reconstructed_data_dict_from(
# --> 134     reconstruction=self.reconstruction
#     135 )
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoconf/tools/decorators.py:16, in CachedProperty.__get__(self, obj, cls)
#      15     return self
# ---> 16 value = obj.__dict__[self.func.__name__] = self.func(obj)
#      17 return value
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/numba_util.py:72, in profile_func.<locals>.wrapper(obj, *args, **kwargs)
#      71 if obj.profiling_dict is None:
# ---> 72     return func(obj, *args, **kwargs)
#      74 repeats = conf.instance["general"]["profiling"]["repeats"]
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/inversion/inversion/matrices.py:148, in InversionMatrices.reconstruction(self)
#     141 """
#     142 Solve the linear system [F + reg_coeff*H] S = D -> S = [F + reg_coeff*H]^-1 D given by equation (12)
#     143 of https://arxiv.org/pdf/astro-ph/0302587.pdf
#     144
#     145 S is the vector of reconstructed inversion values.
#     146 """
# --> 148 return inversion_util.reconstruction_from(
#     149     data_vector=self.data_vector,
#     150     curvature_reg_matrix_cholesky=self.curvature_reg_matrix_cholesky,
#     151     settings=self.settings,
#     152 )
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/inversion/inversion/inversion_util.py:43, in reconstruction_from(data_vector, curvature_reg_matrix_cholesky, settings)
#      42 try:
# ---> 43     reconstruction = cho_solve((curvature_reg_matrix_cholesky, True), data_vector)
#      44 except np.linalg.LinAlgError:
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/scipy/linalg/_decomp_cholesky.py:195, in cho_solve(c_and_lower, b, overwrite_b, check_finite)
#     194     b1 = asarray_chkfinite(b)
# --> 195     c = asarray_chkfinite(c)
#     196 else:
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/numpy/lib/function_base.py:603, in asarray_chkfinite(a, dtype, order)
#     602 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 603     raise ValueError(
#     604         "array must not contain infs or NaNs")
#     605 return a
#
# ValueError: array must not contain infs or NaNs
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 CM.run_current(quiet=False)
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/dyLens/Combined/CombinedModel.py:589, in Model.run_current(self, quiet)
#     587     return self.Pyautolens_figure_of_merit()
#     588 else:
# --> 589     return self.JAM_figure_of_merit() + self.Pyautolens_figure_of_merit()
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/dyLens/Combined/CombinedModel.py:420, in Model.Pyautolens_figure_of_merit(self)
#     418 except:
#     419     print("An exception ocurres in Pyautolens_figure_of_merit().")
# --> 420     print(fit.figure_of_merit)
#     421     self.lens_figure_of_merit = self.stagger_resampling_figure_of_merit()
#     422     self.flag_resampling = 1 #need resampling
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/numba_util.py:72, in profile_func.<locals>.wrapper(obj, *args, **kwargs)
#      58 """
#      59 Time a function and average over repeated calls for profiling an `Analysis` class's likelihood function. The
#      60 time is stored in a `profiling_dict` attribute.
#    (...)
#      69     The result of the function being timed.
#      70 """
#      71 if obj.profiling_dict is None:
# ---> 72     return func(obj, *args, **kwargs)
#      74 repeats = conf.instance["general"]["profiling"]["repeats"]
#      76 last_key_before_call = (
#      77     list(obj.profiling_dict)[-1] if obj.profiling_dict else None
#      78 )
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/fit/fit_dataset.py:241, in FitDataset.figure_of_merit(self)
#     239 if self.inversion is None:
#     240     return self.log_likelihood
# --> 241 return self.log_evidence
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/fit/fit_dataset.py:229, in FitDataset.log_evidence(self)
#     206 """
#     207 Returns the log evidence of the inversion's fit to a dataset, where the log evidence includes a number of terms
#     208 which quantify the complexity of an inversion's reconstruction (see the `LEq` module):
#    (...)
#     225     The normalization noise_map-term for the data's noise-map.
#     226 """
#     227 if self.inversion is not None:
#     228     return fit_util.log_evidence_from(
# --> 229         chi_squared=self.chi_squared,
#     230         regularization_term=self.inversion.regularization_term,
#     231         log_curvature_regularization_term=self.inversion.log_det_curvature_reg_matrix_term,
#     232         log_regularization_term=self.inversion.log_det_regularization_matrix_term,
#     233         noise_normalization=self.noise_normalization,
#     234     )
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/fit/fit_dataset.py:163, in FitDataset.chi_squared(self)
#     159 if self.use_mask_in_fit:
#     160     return fit_util.chi_squared_with_mask_from(
#     161         chi_squared_map=self.chi_squared_map, mask=self.mask
#     162     )
# --> 163 return fit_util.chi_squared_from(chi_squared_map=self.chi_squared_map)
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/fit/fit_dataset.py:151, in FitDataset.chi_squared_map(self)
#     146 if self.use_mask_in_fit:
#     147     return fit_util.chi_squared_map_with_mask_from(
#     148         residual_map=self.residual_map, noise_map=self.noise_map, mask=self.mask
#     149     )
#     150 return fit_util.chi_squared_map_from(
# --> 151     residual_map=self.residual_map, noise_map=self.noise_map
#     152 )
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/fit/fit_dataset.py:122, in FitDataset.residual_map(self)
#     118 if self.use_mask_in_fit:
#     119     return fit_util.residual_map_with_mask_from(
#     120         data=self.data, model_data=self.model_data, mask=self.mask
#     121     )
# --> 122 return fit_util.residual_map_from(data=self.data, model_data=self.model_data)
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autolens/imaging/fit_imaging.py:138, in FitImaging.model_data(self)
#     127 """
#     128 Returns the model-image that is used to fit the data.
#     129
#    (...)
#     133 If a inversion is included it is the sum of this sum and the inversion's reconstruction of the image.
#     134 """
#     136 if self.tracer.has_pixelization:
# --> 138     return self.blurred_image + self.inversion.mapped_reconstructed_data
#     140 return self.blurred_image
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoconf/tools/decorators.py:16, in CachedProperty.__get__(self, obj, cls)
#      14 if obj is None:
#      15     return self
# ---> 16 value = obj.__dict__[self.func.__name__] = self.func(obj)
#      17 return value
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/numba_util.py:72, in profile_func.<locals>.wrapper(obj, *args, **kwargs)
#      58 """
#      59 Time a function and average over repeated calls for profiling an `Analysis` class's likelihood function. The
#      60 time is stored in a `profiling_dict` attribute.
#    (...)
#      69     The result of the function being timed.
#      70 """
#      71 if obj.profiling_dict is None:
# ---> 72     return func(obj, *args, **kwargs)
#      74 repeats = conf.instance["general"]["profiling"]["repeats"]
#      76 last_key_before_call = (
#      77     list(obj.profiling_dict)[-1] if obj.profiling_dict else None
#      78 )
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/inversion/inversion/abstract.py:170, in AbstractInversion.mapped_reconstructed_data(self)
#     155 @cached_property
#     156 @profile_func
#     157 def mapped_reconstructed_data(self) -> Union[Array2D, Visibilities]:
#     158     """
#     159     Using the reconstructed source pixel fluxes we map each source pixel flux back to the image plane and
#     160     reconstruct the image data.
#    (...)
#     168         The reconstructed image data which the inversion fits.
#     169     """
# --> 170     return sum(self.mapped_reconstructed_data_dict.values())
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/inversion/inversion/abstract.py:134, in AbstractInversion.mapped_reconstructed_data_dict(self)
#     117 @property
#     118 def mapped_reconstructed_data_dict(
#     119     self
#     120 ) -> Dict[LinearObj, Union[Array2D, Visibilities]]:
#     121     """
#     122     Using the reconstructed source pixel fluxes we map each source pixel flux back to the image plane and
#     123     reconstruct the image data.
#    (...)
#     131         The reconstructed image data which the inversion fits.
#     132     """
#     133     return self.leq.mapped_reconstructed_data_dict_from(
# --> 134         reconstruction=self.reconstruction
#     135     )
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoconf/tools/decorators.py:16, in CachedProperty.__get__(self, obj, cls)
#      14 if obj is None:
#      15     return self
# ---> 16 value = obj.__dict__[self.func.__name__] = self.func(obj)
#      17 return value
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/numba_util.py:72, in profile_func.<locals>.wrapper(obj, *args, **kwargs)
#      58 """
#      59 Time a function and average over repeated calls for profiling an `Analysis` class's likelihood function. The
#      60 time is stored in a `profiling_dict` attribute.
#    (...)
#      69     The result of the function being timed.
#      70 """
#      71 if obj.profiling_dict is None:
# ---> 72     return func(obj, *args, **kwargs)
#      74 repeats = conf.instance["general"]["profiling"]["repeats"]
#      76 last_key_before_call = (
#      77     list(obj.profiling_dict)[-1] if obj.profiling_dict else None
#      78 )
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/inversion/inversion/matrices.py:148, in InversionMatrices.reconstruction(self)
#     138 @cached_property
#     139 @profile_func
#     140 def reconstruction(self):
#     141     """
#     142     Solve the linear system [F + reg_coeff*H] S = D -> S = [F + reg_coeff*H]^-1 D given by equation (12)
#     143     of https://arxiv.org/pdf/astro-ph/0302587.pdf
#     144
#     145     S is the vector of reconstructed inversion values.
#     146     """
# --> 148     return inversion_util.reconstruction_from(
#     149         data_vector=self.data_vector,
#     150         curvature_reg_matrix_cholesky=self.curvature_reg_matrix_cholesky,
#     151         settings=self.settings,
#     152     )
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/autoarray/inversion/inversion/inversion_util.py:43, in reconstruction_from(data_vector, curvature_reg_matrix_cholesky, settings)
#      17 """
#      18 Solve the linear system [F + reg_coeff*H] S = D -> S = [F + reg_coeff*H]^-1 D given by equation (12)
#      19 of https://arxiv.org/pdf/astro-ph/0302587.pdf
#    (...)
#      40     The curvature_matrix plus regularization matrix, overwriting the curvature_matrix in memory.
#      41 """
#      42 try:
# ---> 43     reconstruction = cho_solve((curvature_reg_matrix_cholesky, True), data_vector)
#      44 except np.linalg.LinAlgError:
#      45     raise exc.InversionException()
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/scipy/linalg/_decomp_cholesky.py:195, in cho_solve(c_and_lower, b, overwrite_b, check_finite)
#     193 if check_finite:
#     194     b1 = asarray_chkfinite(b)
# --> 195     c = asarray_chkfinite(c)
#     196 else:
#     197     b1 = asarray(b)
#
# File ~/anaconda3/envs/dyLens-env/lib/python3.10/site-packages/numpy/lib/function_base.py:603, in asarray_chkfinite(a, dtype, order)
#     601 a = asarray(a, dtype=dtype, order=order)
#     602 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 603     raise ValueError(
#     604         "array must not contain infs or NaNs")
#     605 return a
#
# ValueError: array must not contain infs or NaNs

# %%
einstein_radius = CM.Fit.tracer.einstein_radius_from(CM.Fit.imaging.grid)
einstein_radius
# Out:
# Grid2DIrregular(1.05536364)

# %%
import autolens.plot as aplt
from astropy.io import fits
import matplotlib.pyplot as plt
# Load the original source)
path = "/home/carlos/Documents/GitHub/my_illustris/TNG50-1-snap84-subhalo313415//"
source = fits.open(path+"/lens/source_galaxy.fits")[0].data

interpolated_reconstruction_list = CM.Fit.inversion.interpolated_reconstruction_list_from(
    shape_native=(source.shape[1], source.shape[0]),
)

model = interpolated_reconstruction_list[0].native

plt.figure(figsize=(18,10))

plt.subplot(131)
plt.imshow(source/np.max(source), 
           origin="lower", cmap="rainbow", vmin=0.,)
plt.colorbar()

plt.subplot(132)
plt.imshow(model/np.max(model),
            cmap="rainbow", vmin=0., )
plt.colorbar()

plt.subplot(133)
plt.imshow( (source - model), 
            cmap="rainbow")
plt.colorbar()

# %% [markdown]
# -----

# %%
from jampy.mge_radial_mass import mge_radial_mass
from jampy.mge_half_light_isophote import mge_half_light_isophote
from astropy import units as u


    # Get the effective radius in arcsec, and other quantities
    # See mge_half_light_isophote documentation for more details
reff, reff_maj, eps_e, lum_tot = mge_half_light_isophote(CM.Lens_model.surf_lum,
                                                         CM.Lens_model.sigma_lum,
                                                         CM.Lens_model.qobs_lum,
                                                         CM.Jampy_model.distance)

# %%
#  Model
rad     = 2.5* reff    # 2.5 Reff in arcsec
print(rad)
rad_kpc = ( (rad*u.arcsec * CM.Jampy_model.distance*u.Mpc ).to(
                    u.kpc,u.dimensionless_angles()) ).value # 2.5Reff in kpc


    # Get the radial mass of stars and DM within rad
stellar_mass = mge_radial_mass(CM.Lens_model.surf_lum * CM.ml_model, 
                               CM.Lens_model.sigma_lum, CM.Lens_model.qobs_lum,
                               CM.Jampy_model.inc, rad, CM.Jampy_model.distance)

dm_mass = mge_radial_mass(CM.Jampy_model.surf_dm, 
                               CM.Jampy_model.sigma_dm, CM.Jampy_model.qobs_dm,
                               CM.Jampy_model.inc, rad, CM.Jampy_model.distance)
bh_mass = CM.Lens_model.mbh  # Model BH mass

    # Total Mass
total_mass = stellar_mass + dm_mass
    # Dark matter fraction
dm_fraction = dm_mass / total_mass
# Out:
# 0.8662867097146382

# %%
# Data
    # Changes this path to where are your data
    # Load the snapshot data
dm_dataset   = np.load(path+"/dm/coordinates_dark.npy")
star_dataset = np.load(path+"/imgs/coordinates_star.npy")
    
    # Stellar content
rStar = np.sqrt(np.sum(star_dataset[:, 0:3]**2, axis=1)) # radius
i = rStar <= rad_kpc                                     # only particles within 2.5Reff
Mstar = sum(star_dataset[:, 6][i]*1e10)                  # stellar mass within 2.5Reff



    # Dark content
rDM = np.sqrt(np.sum(dm_dataset[:, 0:3]**2, axis=1))
i = rDM <= rad_kpc
Mdm = sum(dm_dataset[:,3][i]*1e10)

Mbh = 10**8.36 # BH mass from TNG catalogue
    # Total snapshot mass within 2.5Reff
Tmass = Mstar + Mdm
    # DM fraction in the snapshot within 2.5Reff
DM_f = Mdm/Tmass

# %%
print("Model stellar Mass: {:.2e} Msun".format( float(stellar_mass) ))
print("Data  stellar Mass: {:.2e} Msun".format( float(Mstar) ))
f = (stellar_mass - Mstar)/Mstar
print("(Model - Data)/Data: {:.2f}".format( float(f) ))
# Out:
# Model stellar Mass: 1.43e+11 Msun
# Data  stellar Mass: 1.08e+11 Msun
# (Model - Data)/Data: 0.32

# %%
print("Model dm Mass: {:.2e} Msun".format( float(dm_mass) ))
print("Data  dm Mass: {:.2e} Msun".format( float(Mdm) ))
f = (dm_mass - Mdm)/Mdm
print("(Model - Data)/Data: {:.2f}".format( float(f) ))
# Out:
# Model dm Mass: 1.66e+10 Msun
# Data  dm Mass: 5.10e+10 Msun
# (Model - Data)/Data: -0.67

# %%
print("Model total Mass: {:.2e} Msun".format( float(total_mass) ))
print("Data  total Mass: {:.2e} Msun".format( float(Tmass) ))
f = (total_mass - Tmass)/Tmass
print("(Model - Data)/Data: {:.2f}".format( float(f) ))
# Out:
# Model total Mass: 1.59e+11 Msun
# Data  total Mass: 1.59e+11 Msun
# (Model - Data)/Data: 0.00

# %%
print("Model DM fraction: {:.2f}".format( float(dm_fraction) ))
print("Data  DM fraction: {:.2f}".format( float(DM_f) ))
f = (dm_fraction - DM_f)/DM_f
print("(Model - Data)/Data: {:.2f}".format( float(f) ))
# Out:
# Model DM fraction: 0.10
# Data  DM fraction: 0.32
# (Model - Data)/Data: -0.67

# %%
from jampy.mge_radial_density import mge_radial_density

# %%
# Radial Density profile
radii    = np.arange(0.1, 10*reff, 0.01)  # Radii in arcsec
pc       = CM.Jampy_model.distance*np.pi/0.648  # Constant factor to convert arcsec --> pc
radii_pc = radii*pc                   #Radii in pc

dstar = mge_radial_density(CM.Lens_model.surf_lum * CM.ml_model, 
                               CM.Lens_model.sigma_lum, CM.Lens_model.qobs_lum,
                               CM.Jampy_model.inc, radii, CM.Jampy_model.distance)

ddm = mge_radial_density(CM.Jampy_model.surf_dm, 
                               CM.Jampy_model.sigma_dm, CM.Jampy_model.qobs_dm,
                               CM.Jampy_model.inc, radii, CM.Jampy_model.distance)

# Load DM density profile
from astropy.io import fits
dm_hdu = fits.open(path+"/dm/density_fit.fits")
true_density = dm_hdu[1].data["density"]
true_radii = dm_hdu[1].data["radius"]
dm_fit = dm_hdu[1].data["bestfit"]

i = true_radii < radii_pc.max()

true_density = true_density[i]
true_radii   = true_radii[i]
dm_fit = dm_fit[i]

# Stars density profile
star_hdu = fits.open(path+"/imgs/stellar_density.fits")
rho_stars = star_hdu[1].data["density"]
r_star = star_hdu[1].data["radius"]

i = r_star < radii_pc.max()

rho_stars = rho_stars[i]
r_star   = r_star[i]

# %%
import matplotlib.pyplot as plt
plt.rcParams['xtick.labelsize']= 12
plt.rcParams['ytick.labelsize']= 12


plt.figure(figsize=(15,8))

plt.plot(radii_pc, np.log10(dstar), label="star", color="red")
plt.plot(radii_pc, np.log10(ddm), label="dm", color="magenta")
plt.plot(radii_pc, np.log10(ddm+dstar), label="total", color="black")
plt.plot(true_radii, np.log10(dm_fit), label="DM Fit", color="blue", markersize=12)
#plt.plot(radii_pc, np.log10(a), label="MGE", color="black")

plt.plot(true_radii, np.log10(true_density),  ".", label="DM data", color="magenta", markersize=12)
plt.plot(r_star, np.log10(rho_stars),  ".", label="stars data", color="red", markersize=12)
plt.plot(r_star, np.log10(rho_stars+true_density),  ".", label="total", color="black", markersize=12)




plt.title("Density profiles until 10Reff", size=20)
plt.xlabel("radii [pc]", size=20)
plt.ylabel("$\log_{10}(\\frac{\\rho}{M_\odot/pc^3})$", size=20)
plt.legend()
plt.xscale("log")

# %% [markdown]
# ---
